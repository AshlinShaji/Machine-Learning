# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Height weight.csv")
df
# Out:
#     Height  Weight
# 0     1.47   52.21
# 1     1.50   53.12
# 2     1.52   54.48
# 3     1.55   55.84
# 4     1.57   57.20
# 5     1.60   58.57
# 6     1.63   59.93
# 7     1.65   61.29
# 8     1.68   63.11
# 9     1.70   64.47
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
df.shape
# Out:
# (15, 2)

# %%
df.dtypes
# Out:
# Height    float64
# Weight    float64
# dtype: object

# %%
df.tail()
# Out:
#     Height  Weight
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
df.head()
# Out:
#    Height  Weight
# 0    1.47   52.21
# 1    1.50   53.12
# 2    1.52   54.48
# 3    1.55   55.84
# 4    1.57   57.20

# %%
df.isna().sum()
# Out:
# Height    0
# Weight    0
# dtype: int64

# %%
x=df.iloc[:,:-1].values
x
# Out:
# array([[1.47],
#        [1.5 ],
#        [1.52],
#        [1.55],
#        [1.57],
#        [1.6 ],
#        [1.63],
#        [1.65],
#        [1.68],
#        [1.7 ],
#        [1.73],
#        [1.75],
#        [1.78],
#        [1.8 ],
#        [1.83]])

# %%
y=df.iloc[:,-1].values
y
# Out:
# array([52.21, 53.12, 54.48, 55.84, 57.2 , 58.57, 59.93, 61.29, 63.11,
#        64.47, 66.28, 68.1 , 69.92, 72.19, 74.46])

# %%
plt.scatter(x,y)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Heightvs Weight")
# Out:
# Text(0.5, 1.0, 'Heightvs Weight')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
# array([[1.57],
#        [1.5 ],
#        [1.8 ],
#        [1.47],
#        [1.83],
#        [1.7 ],
#        [1.68],
#        [1.78],
#        [1.75],
#        [1.6 ]])

# %%
x_train.ndim
# Out:
# 2

# %%
x_train.shape
# Out:
# (10, 1)

# %%
x_test
# Out:
# array([[1.55],
#        [1.65],
#        [1.63],
#        [1.52],
#        [1.73]])

# %%
x_test.shape
# Out:
# (5, 1)

# %%
y_test
# Out:
# array([55.84, 61.29, 59.93, 54.48, 66.28])

# %%
y_test.shape
# Out:
# (5,)

# %%
y_train
# Out:
# array([57.2 , 53.12, 72.19, 52.21, 74.46, 64.47, 63.11, 69.92, 68.1 ,
#        58.57])

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([56.06758919, 62.22641191, 60.99464737, 54.21994237, 67.15347009])

# %%
y_test
# Out:
# array([55.84, 61.29, 59.93, 54.48, 66.28])

# %%
print(model.predict([[1.87]]))
# Out:
# [75.7758219]

# %%
#data frame

df1=pd.DataFrame({'Actaual':y_test,'Predict':y_pred,'Diffrence':y_test-y_pred})
df1
# Out:
#    Actaual    Predict  Diffrence
# 0    55.84  56.067589  -0.227589
# 1    61.29  62.226412  -0.936412
# 2    59.93  60.994647  -1.064647
# 3    54.48  54.219942   0.260058
# 4    66.28  67.153470  -0.873470

# %%
plt.scatter(x_train,y_train)
plt.plot(x_test,y_pred,color='r')

# %%
print(model.coef_)
# Out:
# [61.58822722]

# %%
print(model.intercept_)
# Out:
# -39.39416300768385

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 0.6724352360043966

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape=mean_absolute_percentage_error(y_test,y_pred)
mape
# Out:
# 0.01101418077856334

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 0.5785436162327637

# %%
from sklearn.metrics import root_mean_squared_error
rmse=root_mean_squared_error(y_test,y_pred)
rmse
# Out:
# 0.7606205468121169

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
score
# Out:
# 0.9671031272342165
