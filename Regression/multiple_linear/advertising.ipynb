# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('advertising.csv')
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
df.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.shape
# Out:
# (200, 4)

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.corr(numeric_only=True)
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
x=df.iloc[:,:-1].values
x
# Out:
# array([[230.1,  37.8,  69.2],
#        [ 44.5,  39.3,  45.1],
#        [ 17.2,  45.9,  69.3],
#        [151.5,  41.3,  58.5],
#        [180.8,  10.8,  58.4],
#        [  8.7,  48.9,  75. ],
#        [ 57.5,  32.8,  23.5],
#        [120.2,  19.6,  11.6],
#        [  8.6,   2.1,   1. ],
#        [199.8,   2.6,  21.2],
#        [ 66.1,   5.8,  24.2],
#        [214.7,  24. ,   4. ],
#        [ 23.8,  35.1,  65.9],
#        [ 97.5,   7.6,   7.2],
#        [204.1,  32.9,  46. ],
#        [195.4,  47.7,  52.9],
#        [ 67.8,  36.6, 114. ],
#        [281.4,  39.6,  55.8],
#        [ 69.2,  20.5,  18.3],
#        [147.3,  23.9,  19.1],
#        [218.4,  27.7,  53.4],
#        [237.4,   5.1,  23.5],
#        [ 13.2,  15.9,  49.6],
#        [228.3,  16.9,  26.2],
#        [ 62.3,  12.6,  18.3],
#        [262.9,   3.5,  19.5],
#        [142.9,  29.3,  12.6],
#        [240.1,  16.7,  22.9],
#        [248.8,  27.1,  22.9],
#        [ 70.6,  16. ,  40.8],
#        [292.9,  28.3,  43.2],
#        [112.9,  17.4,  38.6],
#        [ 97.2,   1.5,  30. ],
#        [265.6,  20. ,   0.3],
#        [ 95.7,   1.4,   7.4],
#        [290.7,   4.1,   8.5],
#        [266.9,  43.8,   5. ],
#        [ 74.7,  49.4,  45.7],
#        [ 43.1,  26.7,  35.1],
#        [228. ,  37.7,  32. ],
#        [202.5,  22.3,  31.6],
#        [177. ,  33.4,  38.7],
#        [293.6,  27.7,   1.8],
#        [206.9,   8.4,  26.4],
#        [ 25.1,  25.7,  43.3],
#        [175.1,  22.5,  31.5],
#        [ 89.7,   9.9,  35.7],
#        [239.9,  41.5,  18.5],
#        [227.2,  15.8,  49.9],
#        [ 66.9,  11.7,  36.8],
#        [199.8,   3.1,  34.6],
#        [100.4,   9.6,   3.6],
#        [216.4,  41.7,  39.6],
#        [182.6,  46.2,  58.7],
#        [262.7,  28.8,  15.9],
#        [198.9,  49.4,  60. ],
#        [  7.3,  28.1,  41.4],
#        [136.2,  19.2,  16.6],
#        [210.8,  49.6,  37.7],
#        [210.7,  29.5,   9.3],
#        [ 53.5,   2. ,  21.4],
#        [261.3,  42.7,  54.7],
#        [239.3,  15.5,  27.3],
#        [102.7,  29.6,   8.4],
#        [131.1,  42.8,  28.9],
#        [ 69. ,   9.3,   0.9],
#        [ 31.5,  24.6,   2.2],
#        [139.3,  14.5,  10.2],
#        [237.4,  27.5,  11. ],
#        [216.8,  43.9,  27.2],
#        [199.1,  30.6,  38.7],
#        [109.8,  14.3,  31.7],
#        [ 26.8,  33. ,  19.3],
#        [129.4,   5.7,  31.3],
#        [213.4,  24.6,  13.1],
#        [ 16.9,  43.7,  89.4],
#        [ 27.5,   1.6,  20.7],
#        [120.5,  28.5,  14.2],
#        [  5.4,  29.9,   9.4],
#        [116. ,   7.7,  23.1],
#        [ 76.4,  26.7,  22.3],
#        [239.8,   4.1,  36.9],
#        [ 75.3,  20.3,  32.5],
#        [ 68.4,  44.5,  35.6],
#        [213.5,  43. ,  33.8],
#        [193.2,  18.4,  65.7],
#        [ 76.3,  27.5,  16. ],
#        [110.7,  40.6,  63.2],
#        [ 88.3,  25.5,  73.4],
#        [109.8,  47.8,  51.4],
#        [134.3,   4.9,   9.3],
#        [ 28.6,   1.5,  33. ],
#        [217.7,  33.5,  59. ],
#        [250.9,  36.5,  72.3],
#        [107.4,  14. ,  10.9],
#        [163.3,  31.6,  52.9],
#        [197.6,   3.5,   5.9],
#        [184.9,  21. ,  22. ],
#        [289.7,  42.3,  51.2],
#        [135.2,  41.7,  45.9],
#        [222.4,   4.3,  49.8],
#        [296.4,  36.3, 100.9],
#        [280.2,  10.1,  21.4],
#        [187.9,  17.2,  17.9],
#        [238.2,  34.3,   5.3],
#        [137.9,  46.4,  59. ],
#        [ 25. ,  11. ,  29.7],
#        [ 90.4,   0.3,  23.2],
#        [ 13.1,   0.4,  25.6],
#        [255.4,  26.9,   5.5],
#        [225.8,   8.2,  56.5],
#        [241.7,  38. ,  23.2],
#        [175.7,  15.4,   2.4],
#        [209.6,  20.6,  10.7],
#        [ 78.2,  46.8,  34.5],
#        [ 75.1,  35. ,  52.7],
#        [139.2,  14.3,  25.6],
#        [ 76.4,   0.8,  14.8],
#        [125.7,  36.9,  79.2],
#        [ 19.4,  16. ,  22.3],
#        [141.3,  26.8,  46.2],
#        [ 18.8,  21.7,  50.4],
#        [224. ,   2.4,  15.6],
#        [123.1,  34.6,  12.4],
#        [229.5,  32.3,  74.2],
#        [ 87.2,  11.8,  25.9],
#        [  7.8,  38.9,  50.6],
#        [ 80.2,   0. ,   9.2],
#        [220.3,  49. ,   3.2],
#        [ 59.6,  12. ,  43.1],
#        [  0.7,  39.6,   8.7],
#        [265.2,   2.9,  43. ],
#        [  8.4,  27.2,   2.1],
#        [219.8,  33.5,  45.1],
#        [ 36.9,  38.6,  65.6],
#        [ 48.3,  47. ,   8.5],
#        [ 25.6,  39. ,   9.3],
#        [273.7,  28.9,  59.7],
#        [ 43. ,  25.9,  20.5],
#        [184.9,  43.9,   1.7],
#        [ 73.4,  17. ,  12.9],
#        [193.7,  35.4,  75.6],
#        [220.5,  33.2,  37.9],
#        [104.6,   5.7,  34.4],
#        [ 96.2,  14.8,  38.9],
#        [140.3,   1.9,   9. ],
#        [240.1,   7.3,   8.7],
#        [243.2,  49. ,  44.3],
#        [ 38. ,  40.3,  11.9],
#        [ 44.7,  25.8,  20.6],
#        [280.7,  13.9,  37. ],
#        [121. ,   8.4,  48.7],
#        [197.6,  23.3,  14.2],
#        [171.3,  39.7,  37.7],
#        [187.8,  21.1,   9.5],
#        [  4.1,  11.6,   5.7],
#        [ 93.9,  43.5,  50.5],
#        [149.8,   1.3,  24.3],
#        [ 11.7,  36.9,  45.2],
#        [131.7,  18.4,  34.6],
#        [172.5,  18.1,  30.7],
#        [ 85.7,  35.8,  49.3],
#        [188.4,  18.1,  25.6],
#        [163.5,  36.8,   7.4],
#        [117.2,  14.7,   5.4],
#        [234.5,   3.4,  84.8],
#        [ 17.9,  37.6,  21.6],
#        [206.8,   5.2,  19.4],
#        [215.4,  23.6,  57.6],
#        [284.3,  10.6,   6.4],
#        [ 50. ,  11.6,  18.4],
#        [164.5,  20.9,  47.4],
#        [ 19.6,  20.1,  17. ],
#        [168.4,   7.1,  12.8],
#        [222.4,   3.4,  13.1],
#        [276.9,  48.9,  41.8],
#        [248.4,  30.2,  20.3],
#        [170.2,   7.8,  35.2],
#        [276.7,   2.3,  23.7],
#        [165.6,  10. ,  17.6],
#        [156.6,   2.6,   8.3],
#        [218.5,   5.4,  27.4],
#        [ 56.2,   5.7,  29.7],
#        [287.6,  43. ,  71.8],
#        [253.8,  21.3,  30. ],
#        [205. ,  45.1,  19.6],
#        [139.5,   2.1,  26.6],
#        [191.1,  28.7,  18.2],
#        [286. ,  13.9,   3.7],
#        [ 18.7,  12.1,  23.4],
#        [ 39.5,  41.1,   5.8],
#        [ 75.5,  10.8,   6. ],
#        [ 17.2,   4.1,  31.6],
#        [166.8,  42. ,   3.6],
#        [149.7,  35.6,   6. ],
#        [ 38.2,   3.7,  13.8],
#        [ 94.2,   4.9,   8.1],
#        [177. ,   9.3,   6.4],
#        [283.6,  42. ,  66.2],
#        [232.1,   8.6,   8.7]])

# %%
y=df.iloc[:,-1].values
y
# Out:
# array([22.1, 10.4, 12. , 16.5, 17.9,  7.2, 11.8, 13.2,  4.8, 15.6, 12.6,
#        17.4,  9.2, 13.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. , 17.5,
#         5.6, 20.5,  9.7, 17. , 15. , 20.9, 18.9, 10.5, 21.4, 11.9, 13.2,
#        17.4, 11.9, 17.8, 25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7, 17.9,
#         8.5, 16.1, 10.6, 23.2, 19.8,  9.7, 16.4, 10.7, 22.6, 21.2, 20.2,
#        23.7,  5.5, 13.2, 23.8, 18.4,  8.1, 24.2, 20.7, 14. , 16. , 11.3,
#        11. , 13.4, 18.9, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9,
#        14.2,  5.3, 11. , 11.8, 17.3, 11.3, 13.6, 21.7, 20.2, 12. , 16. ,
#        12.9, 16.7, 14. ,  7.3, 19.4, 22.2, 11.5, 16.9, 16.7, 20.5, 25.4,
#        17.2, 16.7, 23.8, 19.8, 19.7, 20.7, 15. ,  7.2, 12. ,  5.3, 19.8,
#        18.4, 21.8, 17.1, 20.9, 14.6, 12.6, 12.2,  9.4, 15.9,  6.6, 15.5,
#         7. , 16.6, 15.2, 19.7, 10.6,  6.6, 11.9, 24.7,  9.7,  1.6, 17.7,
#         5.7, 19.6, 10.8, 11.6,  9.5, 20.8,  9.6, 20.7, 10.9, 19.2, 20.1,
#        10.4, 12.3, 10.3, 18.2, 25.4, 10.9, 10.1, 16.1, 11.6, 16.6, 16. ,
#        20.6,  3.2, 15.3, 10.1,  7.3, 12.9, 16.4, 13.3, 19.9, 18. , 11.9,
#        16.9,  8. , 17.2, 17.1, 20. ,  8.4, 17.5,  7.6, 16.7, 16.5, 27. ,
#        20.2, 16.7, 16.8, 17.6, 15.5, 17.2,  8.7, 26.2, 17.6, 22.6, 10.3,
#        17.3, 20.9,  6.7, 10.8, 11.9,  5.9, 19.6, 17.3,  7.6, 14. , 14.8,
#        25.5, 18.4])

# %%
#seaborn
#regplot
sns.regplot(x=df['TV'],y=y,color='r')
# Out:
# <Axes: xlabel='TV'>

# %%
sns.regplot(x=df['Radio'],y=y,color='g')
# Out:
# <Axes: xlabel='Radio'>

# %%
sns.regplot(x=df['Newspaper'],y=y,color='y')
# Out:
# <Axes: xlabel='Newspaper'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
# array([[139.2,  14.3,  25.6],
#        [139.3,  14.5,  10.2],
#        [  5.4,  29.9,   9.4],
#        [293.6,  27.7,   1.8],
#        [281.4,  39.6,  55.8],
#        [  8.7,  48.9,  75. ],
#        [ 80.2,   0. ,   9.2],
#        [137.9,  46.4,  59. ],
#        [227.2,  15.8,  49.9],
#        [ 31.5,  24.6,   2.2],
#        [262.7,  28.8,  15.9],
#        [213.5,  43. ,  33.8],
#        [287.6,  43. ,  71.8],
#        [ 11.7,  36.9,  45.2],
#        [ 17.9,  37.6,  21.6],
#        [209.6,  20.6,  10.7],
#        [ 23.8,  35.1,  65.9],
#        [ 76.4,   0.8,  14.8],
#        [250.9,  36.5,  72.3],
#        [141.3,  26.8,  46.2],
#        [187.8,  21.1,   9.5],
#        [134.3,   4.9,   9.3],
#        [239.8,   4.1,  36.9],
#        [224. ,   2.4,  15.6],
#        [ 75.5,  10.8,   6. ],
#        [ 97.5,   7.6,   7.2],
#        [ 75.3,  20.3,  32.5],
#        [  8.4,  27.2,   2.1],
#        [191.1,  28.7,  18.2],
#        [175.1,  22.5,  31.5],
#        [135.2,  41.7,  45.9],
#        [266.9,  43.8,   5. ],
#        [ 85.7,  35.8,  49.3],
#        [139.5,   2.1,  26.6],
#        [171.3,  39.7,  37.7],
#        [187.9,  17.2,  17.9],
#        [ 38.2,   3.7,  13.8],
#        [177. ,   9.3,   6.4],
#        [ 38. ,  40.3,  11.9],
#        [168.4,   7.1,  12.8],
#        [ 16.9,  43.7,  89.4],
#        [237.4,   5.1,  23.5],
#        [ 28.6,   1.5,  33. ],
#        [197.6,  23.3,  14.2],
#        [ 17.2,  45.9,  69.3],
#        [199.1,  30.6,  38.7],
#        [193.2,  18.4,  65.7],
#        [280.7,  13.9,  37. ],
#        [ 57.5,  32.8,  23.5],
#        [175.7,  15.4,   2.4],
#        [230.1,  37.8,  69.2],
#        [  4.1,  11.6,   5.7],
#        [120.5,  28.5,  14.2],
#        [ 69. ,   9.3,   0.9],
#        [198.9,  49.4,  60. ],
#        [206.8,   5.2,  19.4],
#        [ 88.3,  25.5,  73.4],
#        [  0.7,  39.6,   8.7],
#        [ 89.7,   9.9,  35.7],
#        [239.3,  15.5,  27.3],
#        [213.4,  24.6,  13.1],
#        [217.7,  33.5,  59. ],
#        [243.2,  49. ,  44.3],
#        [172.5,  18.1,  30.7],
#        [104.6,   5.7,  34.4],
#        [110.7,  40.6,  63.2],
#        [156.6,   2.6,   8.3],
#        [140.3,   1.9,   9. ],
#        [117.2,  14.7,   5.4],
#        [ 66.1,   5.8,  24.2],
#        [ 97.2,   1.5,  30. ],
#        [ 68.4,  44.5,  35.6],
#        [ 56.2,   5.7,  29.7],
#        [222.4,   4.3,  49.8],
#        [ 87.2,  11.8,  25.9],
#        [228.3,  16.9,  26.2],
#        [  7.8,  38.9,  50.6],
#        [199.8,   2.6,  21.2],
#        [ 50. ,  11.6,  18.4],
#        [238.2,  34.3,   5.3],
#        [121. ,   8.4,  48.7],
#        [ 48.3,  47. ,   8.5],
#        [241.7,  38. ,  23.2],
#        [286. ,  13.9,   3.7],
#        [131.1,  42.8,  28.9],
#        [195.4,  47.7,  52.9],
#        [177. ,  33.4,  38.7],
#        [163.5,  36.8,   7.4],
#        [255.4,  26.9,   5.5],
#        [ 76.4,  26.7,  22.3],
#        [216.4,  41.7,  39.6],
#        [142.9,  29.3,  12.6],
#        [ 27.5,   1.6,  20.7],
#        [206.9,   8.4,  26.4],
#        [ 62.3,  12.6,  18.3],
#        [151.5,  41.3,  58.5],
#        [284.3,  10.6,   6.4],
#        [ 66.9,  11.7,  36.8],
#        [ 44.7,  25.8,  20.6],
#        [265.2,   2.9,  43. ],
#        [ 39.5,  41.1,   5.8],
#        [292.9,  28.3,  43.2],
#        [ 18.8,  21.7,  50.4],
#        [ 75.1,  35. ,  52.7],
#        [276.9,  48.9,  41.8],
#        [  8.6,   2.1,   1. ],
#        [ 53.5,   2. ,  21.4],
#        [220.3,  49. ,   3.2],
#        [ 44.5,  39.3,  45.1],
#        [136.2,  19.2,  16.6],
#        [ 13.2,  15.9,  49.6],
#        [261.3,  42.7,  54.7],
#        [102.7,  29.6,   8.4],
#        [120.2,  19.6,  11.6],
#        [ 94.2,   4.9,   8.1],
#        [193.7,  35.4,  75.6],
#        [ 76.3,  27.5,  16. ],
#        [197.6,   3.5,   5.9],
#        [237.4,  27.5,  11. ],
#        [199.8,   3.1,  34.6],
#        [220.5,  33.2,  37.9],
#        [149.8,   1.3,  24.3],
#        [ 93.9,  43.5,  50.5],
#        [184.9,  43.9,   1.7],
#        [240.1,   7.3,   8.7],
#        [296.4,  36.3, 100.9],
#        [218.4,  27.7,  53.4],
#        [276.7,   2.3,  23.7],
#        [262.9,   3.5,  19.5],
#        [ 36.9,  38.6,  65.6],
#        [109.8,  14.3,  31.7],
#        [ 59.6,  12. ,  43.1],
#        [ 96.2,  14.8,  38.9],
#        [ 17.2,   4.1,  31.6],
#        [116. ,   7.7,  23.1],
#        [219.8,  33.5,  45.1],
#        [273.7,  28.9,  59.7],
#        [ 26.8,  33. ,  19.3],
#        [ 73.4,  17. ,  12.9],
#        [ 74.7,  49.4,  45.7]])

# %%
x_train.shape
# Out:
# (140, 3)

# %%
x_test
x_test.shape
# Out:
# (60, 3)

# %%
y_train
# Out:
# array([12.2, 13.4,  5.3, 20.7, 24.4,  7.2, 11.9, 15. , 19.8, 11. , 20.2,
#        21.7, 26.2,  7.3,  8. , 20.9,  9.2,  9.4, 22.2, 15.5, 20.6, 14. ,
#        17.3, 16.6, 11.9, 13.7, 11.3,  5.7, 17.3, 16.1, 17.2, 25.4, 13.3,
#        10.3, 16. , 19.7,  7.6, 14.8, 10.9, 16.7,  8.7, 17.5,  7.3, 16.6,
#        12. , 18.3, 20.2, 16.1, 11.8, 17.1, 22.1,  3.2, 14.2, 11.3, 23.7,
#        17.2, 12.9,  1.6, 10.6, 20.7, 17. , 19.4, 25.4, 16.4, 10.4, 16. ,
#        15.5, 10.3, 11.9, 12.6, 13.2, 13.6,  8.7, 16.7, 10.6, 20.5,  6.6,
#        15.6,  8.4, 20.7, 11.6, 11.6, 21.8, 20.9, 16. , 22.4, 17.1, 18. ,
#        19.8, 11.8, 22.6, 15. ,  6.9, 17.9,  9.7, 16.5, 20. ,  9.7, 10.1,
#        17.7, 10.8, 21.4,  7. , 12.6, 27. ,  4.8,  8.1, 24.7, 10.4, 13.2,
#         5.6, 24.2, 14. , 13.2, 14. , 19.2, 12. , 16.7, 18.9, 16.4, 20.1,
#        10.1, 15.3, 20.7, 18.2, 23.8, 18. , 16.8, 17. , 10.8, 12.4,  9.7,
#        12.3,  5.9, 11. , 19.6, 20.8,  8.8, 10.9, 14.7])

# %%
y_test
# Out:
# array([23.8, 16.6, 11.9, 19.8, 17.6, 25.5, 16.9, 17.9, 10.5, 17.1, 17.5,
#        11.3, 17.4, 16.7, 18.4, 15.9, 12.9, 17.8,  9.5, 18.4, 10.7, 12.5,
#         8.5, 11.5, 11.9, 19.9, 10.1, 18.9, 19.6, 20.9, 23.2, 16.9, 17.3,
#        16.7, 20.2, 20.5, 16.5, 11. , 22.3,  7.6,  5.3, 12. ,  6.7, 19. ,
#         5.5, 14.6, 14.6, 21.5, 22.6, 19.7, 25.4, 15.2,  6.6, 21.2, 17.4,
#        17.6, 17.2,  7.2, 18.4,  9.6])

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([21.28816103, 18.04213212, 10.0595901 , 21.08224067, 20.76476044,
#        24.47187353, 16.80643646, 15.62885738, 10.12479884, 18.84601896,
#        15.78389695, 10.54297035, 18.92928707, 15.52557996, 17.8412711 ,
#        15.24120343, 13.74212833, 21.0643733 , 10.05392699, 19.26500889,
#        11.16451173, 11.97211832,  8.61179009, 11.98972141, 12.59914023,
#        16.8447954 ,  9.7170889 , 21.09489946, 18.13942474, 19.55008709,
#        22.08796224, 17.78527998, 16.53883452, 14.77303861, 21.39458945,
#        16.95491635, 17.22755002, 12.31866943, 21.04982199,  7.77473926,
#         5.38467516,  9.63139004,  6.89549204, 19.19507436,  7.88125192,
#        15.18766673, 13.70978421, 21.0232936 , 20.5350058 , 20.48867548,
#        24.86087902, 14.96304281,  7.33545571, 19.35630325, 21.32554066,
#        14.7719757 , 17.19642519,  7.11988693, 18.30096543,  9.65158222])

# %%
y_test
# Out:
# array([23.8, 16.6, 11.9, 19.8, 17.6, 25.5, 16.9, 17.9, 10.5, 17.1, 17.5,
#        11.3, 17.4, 16.7, 18.4, 15.9, 12.9, 17.8,  9.5, 18.4, 10.7, 12.5,
#         8.5, 11.5, 11.9, 19.9, 10.1, 18.9, 19.6, 20.9, 23.2, 16.9, 17.3,
#        16.7, 20.2, 20.5, 16.5, 11. , 22.3,  7.6,  5.3, 12. ,  6.7, 19. ,
#         5.5, 14.6, 14.6, 21.5, 22.6, 19.7, 25.4, 15.2,  6.6, 21.2, 17.4,
#        17.6, 17.2,  7.2, 18.4,  9.6])

# %%
# Data frame

df1=pd.DataFrame({'Actual_data':y_test,'Predicted_data':y_pred,'Diffrence':y_test-y_pred})
df1
# Out:
#     Actual_data  Predicted_data  Diffrence
# 0          23.8       21.288161   2.511839
# 1          16.6       18.042132  -1.442132
# 2          11.9       10.059590   1.840410
# 3          19.8       21.082241  -1.282241
# 4          17.6       20.764760  -3.164760
# 5          25.5       24.471874   1.028126
# 6          16.9       16.806436   0.093564
# 7          17.9       15.628857   2.271143
# 8          10.5       10.124799   0.375201
# 9          17.1       18.846019  -1.746019
# 10         17.5       15.783897   1.716103
# 11         11.3       10.542970   0.757030
# 12         17.4       18.929287  -1.529287
# 13         16.7       15.525580   1.174420
# 14         18.4       17.841271   0.558729
# 15         15.9       15.241203   0.658797
# 16         12.9       13.742128  -0.842128
# 17         17.8       21.064373  -3.264373
# 18          9.5       10.053927  -0.553927
# 19         18.4       19.265009  -0.865009
# 20         10.7       11.164512  -0.464512
# 21         12.5       11.972118   0.527882
# 22          8.5        8.611790  -0.111790
# 23         11.5       11.989721  -0.489721
# 24         11.9       12.599140  -0.699140
# 25         19.9       16.844795   3.055205
# 26         10.1        9.717089   0.382911
# 27         18.9       21.094899  -2.194899
# 28         19.6       18.139425   1.460575
# 29         20.9       19.550087   1.349913
# 30         23.2       22.087962   1.112038
# 31         16.9       17.785280  -0.885280
# 32         17.3       16.538835   0.761165
# 33         16.7       14.773039   1.926961
# 34         20.2       21.394589  -1.194589
# 35         20.5       16.954916   3.545084
# 36         16.5       17.227550  -0.727550
# 37         11.0       12.318669  -1.318669
# 38         22.3       21.049822   1.250178
# 39          7.6        7.774739  -0.174739
# 40          5.3        5.384675  -0.084675
# 41         12.0        9.631390   2.368610
# 42          6.7        6.895492  -0.195492
# 43         19.0       19.195074  -0.195074
# 44          5.5        7.881252  -2.381252
# 45         14.6       15.187667  -0.587667
# 46         14.6       13.709784   0.890216
# 47         21.5       21.023294   0.476706
# 48         22.6       20.535006   2.064994
# 49         19.7       20.488675  -0.788675
# 50         25.4       24.860879   0.539121
# 51         15.2       14.963043   0.236957
# 52          6.6        7.335456  -0.735456
# 53         21.2       19.356303   1.843697
# 54         17.4       21.325541  -3.925541
# 55         17.6       14.771976   2.828024
# 56         17.2       17.196425   0.003575
# 57          7.2        7.119887   0.080113
# 58         18.4       18.300965   0.099035
# 59          9.6        9.651582  -0.051582

# %%
print(model.coef_)
# Out:
# [ 0.05502392  0.10251003 -0.00150711]

# %%
print(model.intercept_)
# Out:
# 4.661439720130813

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 1.1947417134056737

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape=mean_absolute_percentage_error(y_test,y_pred)
mape
# Out:
# 0.07695080788726724

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 2.370659971225658

# %%
from sklearn.metrics import root_mean_squared_error
rmse=root_mean_squared_error(y_test,y_pred)
rmse
# Out:
# 1.5396947656031237

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
score
# Out:
# 0.9071151423684273
