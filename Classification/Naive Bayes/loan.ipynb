# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("loan_train.csv")
df
# Out:
#      Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0      Male      No          0      Graduate            No            584900
# 1      Male     Yes          1      Graduate            No            458300
# 2      Male     Yes          0      Graduate           Yes            300000
# 3      Male     Yes          0  Not Graduate            No            258300
# 4      Male      No          0      Graduate            No            600000
# ..      ...     ...        ...           ...           ...               ...
# 609  Female      No          0      Graduate            No            290000
# 610    Male     Yes         3+      Graduate            No            410600
# 611    Male     Yes          1      Graduate            No            807200
# 612    Male     Yes          2      Graduate            No            758300
# 613  Female      No          0      Graduate           Yes            458300
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History       Area Status
# 0                   0.0     15000000  360.0             1.0      Urban      Y
# 1              150800.0     12800000  360.0             1.0      Rural      N
# 2                   0.0      6600000  360.0             1.0      Urban      Y
# 3              235800.0     12000000  360.0             1.0      Urban      Y
# 4                   0.0     14100000  360.0             1.0      Urban      Y
# ..                  ...          ...    ...             ...        ...    ...
# 609                 0.0      7100000  360.0             1.0      Rural      Y
# 610                 0.0      4000000  180.0             1.0      Rural      Y
# 611             24000.0     25300000  360.0             1.0      Urban      Y
# 612                 0.0     18700000  360.0             1.0      Urban      Y
# 613                 0.0     13300000  360.0             0.0  Semiurban      N
#
# [614 rows x 12 columns]

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0   Male      No          0      Graduate            No            584900
# 1   Male     Yes          1      Graduate            No            458300
# 2   Male     Yes          0      Graduate           Yes            300000
# 3   Male     Yes          0  Not Graduate            No            258300
# 4   Male      No          0      Graduate            No            600000
#
#    Coapplicant_Income  Loan_Amount   Term  Credit_History   Area Status
# 0                 0.0     15000000  360.0             1.0  Urban      Y
# 1            150800.0     12800000  360.0             1.0  Rural      N
# 2                 0.0      6600000  360.0             1.0  Urban      Y
# 3            235800.0     12000000  360.0             1.0  Urban      Y
# 4                 0.0     14100000  360.0             1.0  Urban      Y

# %%
df.tail()
# Out:
#      Gender Married Dependents Education Self_Employed  Applicant_Income  \
# 609  Female      No          0  Graduate            No            290000
# 610    Male     Yes         3+  Graduate            No            410600
# 611    Male     Yes          1  Graduate            No            807200
# 612    Male     Yes          2  Graduate            No            758300
# 613  Female      No          0  Graduate           Yes            458300
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History       Area Status
# 609                 0.0      7100000  360.0             1.0      Rural      Y
# 610                 0.0      4000000  180.0             1.0      Rural      Y
# 611             24000.0     25300000  360.0             1.0      Urban      Y
# 612                 0.0     18700000  360.0             1.0      Urban      Y
# 613                 0.0     13300000  360.0             0.0  Semiurban      N

# %%
df.shape
# Out:
# (614, 12)

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Applicant_Income', 'Coapplicant_Income', 'Loan_Amount', 'Term',
#        'Credit_History', 'Area', 'Status'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Gender                13
# Married                3
# Dependents            15
# Education              0
# Self_Employed         32
# Applicant_Income       0
# Coapplicant_Income     0
# Loan_Amount            0
# Term                  14
# Credit_History        50
# Area                   0
# Status                 0
# dtype: int64

# %%
df.dtypes
# Out:
# Gender                 object
# Married                object
# Dependents             object
# Education              object
# Self_Employed          object
# Applicant_Income        int64
# Coapplicant_Income    float64
# Loan_Amount             int64
# Term                  float64
# Credit_History        float64
# Area                   object
# Status                 object
# dtype: object

# %%
df1=df['Gender'].value_counts()
df1
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
plt.bar(df1.index,df1.values)
# Out:
# <BarContainer object of 2 artists>

# %%
df2=df['Married'].value_counts()
df2
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
plt.bar(df2.index,df2.values)
# Out:
# <BarContainer object of 2 artists>

# %%
df3=df['Education'].value_counts()
df3
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
plt.bar(df3.index,df3.values)
# Out:
# <BarContainer object of 2 artists>

# %%
df['Self_Employed'].value_counts()
# Out:
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64

# %%
df['Area'].value_counts()
# Out:
# Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df['Married']=df['Married'].fillna(df['Married'].mode()[0])

# %%
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])

# %%
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df['Term']=df['Term'].fillna(df['Term'].mode()[0])

# %%
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mode()[0])

# %%
df=df.drop(['Gender'],axis=1)

# %%
df.tail()
# Out:
#     Married Dependents Education Self_Employed  Applicant_Income  \
# 609      No          0  Graduate            No            290000
# 610     Yes         3+  Graduate            No            410600
# 611     Yes          1  Graduate            No            807200
# 612     Yes          2  Graduate            No            758300
# 613      No          0  Graduate           Yes            458300
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History       Area Status
# 609                 0.0      7100000  360.0             1.0      Rural      Y
# 610                 0.0      4000000  180.0             1.0      Rural      Y
# 611             24000.0     25300000  360.0             1.0      Urban      Y
# 612                 0.0     18700000  360.0             1.0      Urban      Y
# 613                 0.0     13300000  360.0             0.0  Semiurban      N

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
df['Married']=lab.fit_transform(df['Married'])
df['Dependents']=lab.fit_transform(df['Dependents'])
df['Education']=lab.fit_transform(df['Education'])
df['Self_Employed']=lab.fit_transform(df['Self_Employed'])
df['Area']=lab.fit_transform(df['Area'])
df
# Out:
#      Married  Dependents  Education  Self_Employed  Applicant_Income  \
# 0          0           0          0              0            584900
# 1          1           1          0              0            458300
# 2          1           0          0              1            300000
# 3          1           0          1              0            258300
# 4          0           0          0              0            600000
# ..       ...         ...        ...            ...               ...
# 609        0           0          0              0            290000
# 610        1           3          0              0            410600
# 611        1           1          0              0            807200
# 612        1           2          0              0            758300
# 613        0           0          0              1            458300
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History  Area Status
# 0                   0.0     15000000  360.0             1.0     2      Y
# 1              150800.0     12800000  360.0             1.0     0      N
# 2                   0.0      6600000  360.0             1.0     2      Y
# 3              235800.0     12000000  360.0             1.0     2      Y
# 4                   0.0     14100000  360.0             1.0     2      Y
# ..                  ...          ...    ...             ...   ...    ...
# 609                 0.0      7100000  360.0             1.0     0      Y
# 610                 0.0      4000000  180.0             1.0     0      Y
# 611             24000.0     25300000  360.0             1.0     2      Y
# 612                 0.0     18700000  360.0             1.0     2      Y
# 613                 0.0     13300000  360.0             0.0     1      N
#
# [614 rows x 11 columns]

# %%
x=df.iloc[:,:-1]
x
# Out:
#      Married  Dependents  Education  Self_Employed  Applicant_Income  \
# 0          0           0          0              0            584900
# 1          1           1          0              0            458300
# 2          1           0          0              1            300000
# 3          1           0          1              0            258300
# 4          0           0          0              0            600000
# ..       ...         ...        ...            ...               ...
# 609        0           0          0              0            290000
# 610        1           3          0              0            410600
# 611        1           1          0              0            807200
# 612        1           2          0              0            758300
# 613        0           0          0              1            458300
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History  Area
# 0                   0.0     15000000  360.0             1.0     2
# 1              150800.0     12800000  360.0             1.0     0
# 2                   0.0      6600000  360.0             1.0     2
# 3              235800.0     12000000  360.0             1.0     2
# 4                   0.0     14100000  360.0             1.0     2
# ..                  ...          ...    ...             ...   ...
# 609                 0.0      7100000  360.0             1.0     0
# 610                 0.0      4000000  180.0             1.0     0
# 611             24000.0     25300000  360.0             1.0     2
# 612                 0.0     18700000  360.0             1.0     2
# 613                 0.0     13300000  360.0             0.0     1
#
# [614 rows x 10 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Status, Length: 614, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.30,random_state=1)
x_train
# Out:
#      Married  Dependents  Education  Self_Employed  Applicant_Income  \
# 310        0           0          0              0            291700
# 48         1           0          0              0            264500
# 83         1           0          0              0            600000
# 535        0           0          1              0            255000
# 33         1           0          0              0            350000
# ..       ...         ...        ...            ...               ...
# 129        1           0          0              0            608000
# 144        1           2          0              0           1175700
# 72         0           0          0              0            350000
# 235        1           1          0              0            550000
# 37         1           0          0              0            366700
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History  Area
# 310                 0.0      8400000  360.0             1.0     1
# 48             344000.0     12000000  360.0             0.0     2
# 83             225000.0     26500000  360.0             1.0     1
# 535            204200.0     12600000  360.0             1.0     0
# 33             166700.0     11400000  360.0             1.0     1
# ..                  ...          ...    ...             ...   ...
# 129            256900.0     18200000  360.0             1.0     0
# 144                 0.0     18700000  180.0             1.0     2
# 72                  0.0      8100000  300.0             1.0     1
# 235            126000.0     17000000  360.0             1.0     0
# 37             145900.0     14400000  360.0             1.0     1
#
# [184 rows x 10 columns]

# %%
x_train.shape
# Out:
# (184, 10)

# %%
x_test
# Out:
#      Married  Dependents  Education  Self_Employed  Applicant_Income  \
# 533        0           1          0              0           1125000
# 544        1           0          1              0            301700
# 41         0           0          0              0            180000
# 148        0           0          0              0           1000000
# 111        1           0          0              0            292900
# ..       ...         ...        ...            ...               ...
# 527        1           1          1              0            528500
# 55         1           2          0              0            270800
# 156        1           1          0              0            600000
# 539        1           3          0              0            641700
# 550        1           2          0              1            663300
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History  Area
# 533                 0.0     19600000  360.0             1.0     1
# 544             66300.0     10200000  360.0             1.0     1
# 41             121300.0      4700000  360.0             1.0     2
# 148            166600.0     22500000  360.0             1.0     0
# 111            233300.0     13900000  360.0             1.0     1
# ..                  ...          ...    ...             ...   ...
# 527            143000.0     16100000  360.0             0.0     1
# 55             116700.0      9700000  360.0             1.0     1
# 156                 0.0     16000000  360.0             1.0     0
# 539                 0.0     15700000  180.0             1.0     0
# 550                 0.0            0  360.0             0.0     0
#
# [430 rows x 10 columns]

# %%
x_test.shape
# Out:
# (430, 10)

# %%
y_train
# Out:
# 310    Y
# 48     N
# 83     N
# 535    Y
# 33     Y
#       ..
# 129    N
# 144    Y
# 72     Y
# 235    Y
# 37     Y
# Name: Status, Length: 184, dtype: object

# %%
y_train.shape
# Out:
# (184,)

# %%
y_test
# Out:
# 533    N
# 544    Y
# 41     Y
# 148    N
# 111    Y
#       ..
# 527    Y
# 55     Y
# 156    Y
# 539    Y
# 550    N
# Name: Status, Length: 430, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit_transform(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)

# %%
x_train
# Out:
# array([[-1.55158223, -0.78225391, -0.51861886, ...,  0.28303278,
#          0.40565621,  0.11532599],
#        [ 0.64450339, -0.78225391, -0.51861886, ...,  0.28303278,
#         -2.46514159,  1.44157483],
#        [ 0.64450339, -0.78225391, -0.51861886, ...,  0.28303278,
#          0.40565621,  0.11532599],
#        ...,
#        [-1.55158223, -0.78225391, -0.51861886, ..., -0.6210997 ,
#          0.40565621,  0.11532599],
#        [ 0.64450339,  0.21039933, -0.51861886, ...,  0.28303278,
#          0.40565621, -1.21092286],
#        [ 0.64450339, -0.78225391, -0.51861886, ...,  0.28303278,
#          0.40565621,  0.11532599]], shape=(184, 10))

# %%
x_test
# Out:
# array([[-1.55158223,  0.21039933, -0.51861886, ...,  0.28303278,
#          0.40565621,  0.11532599],
#        [ 0.64450339, -0.78225391,  1.92819831, ...,  0.28303278,
#          0.40565621,  0.11532599],
#        [-1.55158223, -0.78225391, -0.51861886, ...,  0.28303278,
#          0.40565621,  1.44157483],
#        ...,
#        [ 0.64450339,  0.21039933, -0.51861886, ...,  0.28303278,
#          0.40565621, -1.21092286],
#        [ 0.64450339,  2.19570581, -0.51861886, ..., -2.42936465,
#          0.40565621, -1.21092286],
#        [ 0.64450339,  1.20305257, -0.51861886, ...,  0.28303278,
#         -2.46514159, -1.21092286]], shape=(430, 10))

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'N',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'N', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'N'], dtype='<U1')

# %%
y_test
# Out:
# 533    N
# 544    Y
# 41     Y
# 148    N
# 111    Y
#       ..
# 527    Y
# 55     Y
# 156    Y
# 539    Y
# 550    N
# Name: Status, Length: 430, dtype: object

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,ConfusionMatrixDisplay
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[ 62,  72],
#        [ 13, 283]])

# %%
score=accuracy_score(y_test,y_pred)
score
# Out:
# 0.8023255813953488

# %%
lab=['Y','N']
cmd=ConfusionMatrixDisplay(cm,display_labels=lab)
cmd.plot()
